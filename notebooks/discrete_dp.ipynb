# %% [markdown]
# Modified from https://lectures.quantecon.org/jl/discrete_dp.html#exercises

# %%
#Pass in parameters
function SimpleOG(p)
    B, M, α, β = p.B, p.M, p.α, p.β
    u(c) = c^α
    n = B + M + 1
    m = M + 1

    R = zeros(n, m)
    Q = zeros(n,m,n)

    for a in 0:M
        Q[:, a + 1, (a:(a + B)) + 1] = 1 / (B + 1)
        for s in 0:(B + M)
            if a<=s               
                R[s + 1, a + 1] = u(s - a) 
            else
                R[s + 1, a + 1] =  -Inf
            end
        end
    end

    return R, Q
end
# Out:
# SimpleOG (generic function with 1 method)

# %%
#More Verbose version creating Q and R
function VerboseOG(p)
    B, M, α, β = p.B, p.M, p.α, p.β
    u(c) = c^α
    
    #Matrix dimensions. The +1 is due to the 0 state.
    n = B + M + 1
    m = M + 1

    R = fill(-Inf, n, m) #Start assuming nothing is feasible
    Q = zeros(n,m,n) #Assume 0 by default

    #Create the R matrix
    #Note: indexing into matrix complicated since Julia starts indexing at 1 instead of 0
    #but the state s and choice a can be 0
    for a in 0:M
         for s in 0:(B + M)
            if a <= s #i.e. if feasible
                R[s + 1, a + 1] = u(s - a) 
            end
        end
    end
    
    #Create the Q multi-array
    for s in 0:(B+M) #For each state
        for a in 0:M #For each action
            for sp in 0:(B+M) #For each state next period
                if( sp >= a && sp <= a + B) # The support of all realizations
                    Q[s + 1, a + 1, sp + 1] = 1 / (B + 1) # Same prob of all
                end
            end
            @assert sum(Q[s + 1, a + 1, :]) ≈ 1 #Optional check that matrix is stochastic
         end
    end

    return R, Q
end
# Out:
# VerboseOG (generic function with 1 method)

# %%
using QuantEcon, NamedTuples
params = @NT(β = 0.9, B = 10, M = 5, α=0.5)

R, Q = SimpleOG(params)
R2, Q2 = VerboseOG(params)

@show Q ≈ Q2
@show R ≈ R2
ddp = DiscreteDP(R, Q, params.β)
results = solve(ddp, PFI)
fieldnames(results)
# Out:
# Q ≈ Q2 = true
# R ≈ R2 = true
# 5-element Array{Symbol,1}:
#  :v
#  :Tv
#  :num_iter
#  :sigma
#  :mc

# %%
results.v
# Out:
# 16-element Array{Float64,1}:
#  19.0174
#  20.0174
#  20.4316
#  20.7495
#  21.0408
#  21.3087
#  21.5448
#  21.7693
#  21.9827
#  22.1882
#  22.3845
#  22.5781
#  22.7611
#  22.9438
#  23.1153
#  23.2776

# %%
results.sigma - 1
# Out:
# 16-element Array{Int64,1}:
#  0
#  0
#  0
#  0
#  1
#  1
#  1
#  2
#  2
#  3
#  3
#  4
#  5
#  5
#  5
#  5

# %%
using Plots
gr()
bar(stationary_distributions(results.mc)[1], label="stationary dist")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip7600">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7601">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7600)" points="
# 39.1651,375.869 580.315,375.869 580.315,11.811 39.1651,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7602">
#     <rect x="39" y="11" width="542" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   132.028,375.869 132.028,11.811
#   "/>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   228.962,375.869 228.962,11.811
#   "/>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   325.896,375.869 325.896,11.811
#   "/>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   422.83,375.869 422.83,11.811
#   "/>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   519.764,375.869 519.764,11.811
#   "/>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1651,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1651,295.776 580.315,295.776
#   "/>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1651,215.683 580.315,215.683
#   "/>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1651,135.591 580.315,135.591
#   "/>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1651,55.4979 580.315,55.4979
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,375.869 39.1651,11.811
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   132.028,375.869 132.028,370.408
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   228.962,375.869 228.962,370.408
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   325.896,375.869 325.896,370.408
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   422.83,375.869 422.83,370.408
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   519.764,375.869 519.764,370.408
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,375.869 47.2823,375.869
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,295.776 47.2823,295.776
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,215.683 47.2823,215.683
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,135.591 47.2823,135.591
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,55.4979 47.2823,55.4979
#   "/>
# <g clip-path="url(#clip7600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 132.028, 389.669)" x="132.028" y="389.669">3</text>
# </g>
# <g clip-path="url(#clip7600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 228.962, 389.669)" x="228.962" y="389.669">6</text>
# </g>
# <g clip-path="url(#clip7600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 325.896, 389.669)" x="325.896" y="389.669">9</text>
# </g>
# <g clip-path="url(#clip7600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 422.83, 389.669)" x="422.83" y="389.669">12</text>
# </g>
# <g clip-path="url(#clip7600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0,